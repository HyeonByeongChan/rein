# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Categorical
import numpy as np
import matplotlib.pyplot as plt

class EarthquakeEscapeEnv:
    def __init__(self, width=5, height=5, depth=3):
        self.width = width
        self.height = height
        self.depth = depth
        self.building = np.zeros((depth, height, width), dtype=int)

        # Define obstacles
        self.building[0, 2, 2] = -1  # Obstacle at (0, 2, 2)
        self.building[1, 1, 1] = -1  # Obstacle at (1, 1, 1)
        self.building[2, 3, 3] = -1  # Obstacle at (2, 3, 3)

        # Define the exit location
        self.exit_location = (0, 0, 0)  # Exit at (0, 0, 0)

        # Initial position of the agent
        self.start_location = (2, 4, 4)  # Start at (2, 4, 4)
        self.agent_position = self.start_location

    def reset(self):
        self.agent_position = self.start_location
        return self.agent_position

    def step(self, action):
        z, y, x = self.agent_position

        if action == 0:  # move up
            y = max(0, y - 1)
        elif action == 1:  # move down
            y = min(self.height - 1, y + 1)
        elif action == 2:  # move left
            x = max(0, x - 1)
        elif action == 3:  # move right
            x = min(self.width - 1, x + 1)
        elif action == 4:  # move up a floor
            z = max(0, z - 1)
        elif action == 5:  # move down a floor
            z = min(self.depth - 1, z + 1)

        # Check bounds and obstacles
        if 0 <= x < self.width and 0 <= y < self.height and 0 <= z < self.depth:
            if self.building[z, y, x] != -1:
                self.agent_position = (z, y, x)

        reward = -1  # Default step penalty
        done = False

        if self.agent_position == self.exit_location:
            reward = 100  # 출구에 도착하면 높은 보상 부여
            done = True
        else:
            # 에이전트가 출구에 가까워질수록 보상이 증가하도록 함
            distance_to_exit = abs(self.agent_position[0] - self.exit_location[0]) + \
                                abs(self.agent_position[1] - self.exit_location[1]) + \
                                abs(self.agent_position[2] - self.exit_location[2])
            reward = -distance_to_exit  # 출구에 가까울수록 높은 보상 부여
            done = False

        return self.agent_position, reward, done




class PolicyNetwork(nn.Module):
    def __init__(self, input_size, output_size):
        super(PolicyNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, output_size)
    
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.softmax(x, dim=-1)

class ValueNetwork(nn.Module):
    def __init__(self, input_size):
        super(ValueNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 1)
    
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

class PPOAgent:
    def __init__(self, env, gamma=0.99, lr=3e-4, clip_eps=0.2, update_steps=10):
        self.env = env
        self.gamma = gamma
        self.clip_eps = clip_eps
        self.update_steps = update_steps

        self.policy_net = PolicyNetwork(3, 6).cuda()
        self.value_net = ValueNetwork(3).cuda()

        self.policy_optimizer = optim.Adam(self.policy_net.parameters(), lr=lr)
        self.value_optimizer = optim.Adam(self.value_net.parameters(), lr=lr)
    
    def select_action(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).cuda()
        with torch.no_grad():  # 그래디언트 추적 비활성화
            probs = self.policy_net(state_tensor)
            dist = Categorical(probs)
            action = dist.sample()
            log_prob = dist.log_prob(action)
        return action.item(), log_prob

    def update(self, states, actions, log_probs, returns, advantages):
        for _ in range(self.update_steps):
            idxs = np.arange(len(states))
            np.random.shuffle(idxs)
            for i in idxs:
                state = torch.tensor(states[i], dtype=torch.float32).cuda()
                action = torch.tensor(actions[i]).cuda()
                old_log_prob = log_probs[i].cuda()
                R = returns[i]
                advantage = advantages[i]

                prob = self.policy_net(state.unsqueeze(0))
                dist = Categorical(prob)
                new_log_prob = dist.log_prob(action)

                ratio = torch.exp(new_log_prob - old_log_prob)
                surr1 = ratio * advantage
                surr2 = torch.clamp(ratio, 1 - self.clip_eps, 1 + self.clip_eps) * advantage

                policy_loss = -(torch.min(surr1, surr2)).mean()
                value_loss = ((self.value_net(state.unsqueeze(0)) - R).pow(2)).mean()

                self.policy_optimizer.zero_grad()
                policy_loss.backward()
                self.policy_optimizer.step()

                self.value_optimizer.zero_grad()
                value_loss.backward()
                self.value_optimizer.step()



    def compute_returns(self, rewards, dones):
        returns = []
        R = 0
        for r, done in zip(reversed(rewards), reversed(dones)):
            if done:
                R = 0
            R = r + self.gamma * R
            returns.insert(0, R)
        return returns

    
    def train(self, num_episodes):
        episode_rewards, episode_lengths = [], []

        for episode in range(num_episodes):
            state = env.reset()
            episode_reward = 0
            episode_length = 0
        
            # 추가된 로깅: 에피소드 시작 메시지 출력
            print(f"Episode {episode + 1} started.")
        
            done = False
            while not done:
                action, log_prob = agent.select_action(state)
                next_state, reward, done = env.step(action)
        
        
                # 학습에 필요한 데이터 수집
                episode_reward += reward
                episode_length += 1
        
                # 상태 업데이트
                state = next_state
        
            # 추가된 로깅: 에피소드 종료 메시지 및 결과 출력
            print(f"Episode {episode + 1} finished. Total reward: {episode_reward}, Length: {episode_length}")
        
            # 에피소드별 보상 및 길이 저장
            episode_rewards.append(episode_reward)
            episode_lengths.append(episode_length)
    
        return episode_rewards, episode_lengths

# %%
import os

# 학습 및 성능 평가
env = EarthquakeEscapeEnv()
agent = PPOAgent(env)

# Anomaly detection 활성화
torch.autograd.set_detect_anomaly(True)
episode_rewards, episode_lengths = agent.train(num_episodes=1000)


# 학습 결과 저장
torch.save(agent.policy_net.state_dict(), 'policy_net.pth')
torch.save(agent.value_net.state_dict(), 'value_net.pth')

# 학습 과정 로깅
print("Training completed. Saving models and plotting training results...")

# 성능 비교 시각화
plt.figure(figsize=(10, 5))

# 에피소드별 보상 그래프
plt.subplot(1, 2, 1)
plt.plot(episode_rewards, label='Training')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

# 에피소드별 길이 그래프
plt.subplot(1, 2, 2)
plt.plot(episode_lengths, label='Training')
plt.title('Episode Lengths')
plt.xlabel('Episode')
plt.ylabel('Length')
plt.legend()

plt.tight_layout()
plt.show()

# 이전 체크포인트 로드
policy_net = PolicyNetwork(3, 6).cuda()
value_net = ValueNetwork(3).cuda()

policy_net.load_state_dict(torch.load('policy_net.pth'))
value_net.load_state_dict(torch.load('value_net.pth'))

# 성능 평가를 위한 에이전트 생성
eval_agent = PPOAgent(env)

# 성능 비교를 위한 변수 초기화
eval_episode_rewards = []
eval_episode_lengths = []

# 평가
print("Evaluating the trained model...")
for _ in range(100):  # 100 에피소드 동안 평가
    state = env.reset()
    total_reward = 0
    episode_length = 0
    done = False

    while not done:
        action, _ = eval_agent.select_action(state)
        next_state, reward, done = env.step(action)

        total_reward += reward
        episode_length += 1
        state = next_state

    eval_episode_rewards.append(total_reward)
    eval_episode_lengths.append(episode_length)

# 성능 비교 시각화
plt.figure(figsize=(10, 5))

# 에피소드별 보상 그래프
plt.subplot(1, 2, 1)
plt.plot(episode_rewards, label='Training')
plt.plot(eval_episode_rewards, label='Evaluation')
plt.title('Episode Rewards')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

# 에피소드별 길이 그래프
plt.subplot(1, 2, 2)
plt.plot(episode_lengths, label='Training')
plt.plot(eval_episode_lengths, label='Evaluation')
plt.title('Episode Lengths')
plt.xlabel('Episode')
plt.ylabel('Length')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Episode 1 started.
# Step: 1, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 2, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 3, State: (2, 4, 2), Action: 0, Reward: -7
# Step: 4, State: (2, 3, 2), Action: 1, Reward: -8
# Step: 5, State: (2, 4, 2), Action: 1, Reward: -8
# Step: 6, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 7, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 8, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 9, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 10, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 11, State: (1, 3, 2), Action: 4, Reward: -5
# Step: 12, State: (0, 3, 2), Action: 0, Reward: -5
# Step: 13, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 14, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 15, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 16, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 17, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 18, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 19, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 20, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 21, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 22, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 23, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 24, State: (0, 4, 0), Action: 2, Reward: -4
# Step: 25, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 26, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 27, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 28, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 29, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 30, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 31, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 32, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 33, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 34, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 35, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 36, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 37, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 38, State: (0, 4, 0), Action: 2, Reward: -4
# Step: 39, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 40, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 41, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 42, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 43, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 44, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 45, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 46, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 47, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 48, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 49, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 50, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 51, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 52, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 53, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 54, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 55, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 56, State: (1, 4, 1), Action: 5, Reward: -7
# Step: 57, State: (2, 4, 1), Action: 4, Reward: -6
# Step: 58, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 59, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 60, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 61, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 62, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 63, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 64, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 65, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 66, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 67, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 68, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 69, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 70, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 71, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 72, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 73, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 74, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 75, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 76, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 77, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 78, State: (1, 3, 0), Action: 3, Reward: -5
# Step: 79, State: (1, 3, 1), Action: 1, Reward: -6
# Step: 80, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 81, State: (0, 4, 1), Action: 3, Reward: -6
# Step: 82, State: (0, 4, 2), Action: 5, Reward: -7
# Step: 83, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 84, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 85, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 86, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 87, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 88, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 89, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 90, State: (0, 4, 0), Action: 2, Reward: -4
# Step: 91, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 92, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 93, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 94, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 95, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 96, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 97, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 98, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 99, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 100, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 101, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 102, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 103, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 104, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 105, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 106, State: (2, 3, 0), Action: 0, Reward: -4
# Step: 107, State: (2, 2, 0), Action: 4, Reward: -3
# Step: 108, State: (1, 2, 0), Action: 2, Reward: -3
# Step: 109, State: (1, 2, 0), Action: 5, Reward: -4
# Step: 110, State: (2, 2, 0), Action: 3, Reward: -5
# Step: 111, State: (2, 2, 1), Action: 0, Reward: -4
# Step: 112, State: (2, 1, 1), Action: 5, Reward: -4
# Step: 113, State: (2, 1, 1), Action: 1, Reward: -5
# Step: 114, State: (2, 2, 1), Action: 4, Reward: -4
# Step: 115, State: (1, 2, 1), Action: 1, Reward: -5
# Step: 116, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 117, State: (0, 3, 1), Action: 5, Reward: -5
# Step: 118, State: (1, 3, 1), Action: 1, Reward: -6
# Step: 119, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 120, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 121, State: (1, 4, 3), Action: 4, Reward: -7
# Step: 122, State: (0, 4, 3), Action: 0, Reward: -6
# Step: 123, State: (0, 3, 3), Action: 0, Reward: -5
# Step: 124, State: (0, 2, 3), Action: 1, Reward: -6
# Step: 125, State: (0, 3, 3), Action: 5, Reward: -7
# Step: 126, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 127, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 128, State: (1, 4, 4), Action: 3, Reward: -9
# Step: 129, State: (1, 4, 4), Action: 1, Reward: -9
# Step: 130, State: (1, 4, 4), Action: 4, Reward: -8
# Step: 131, State: (0, 4, 4), Action: 0, Reward: -7
# Step: 132, State: (0, 3, 4), Action: 3, Reward: -7
# Step: 133, State: (0, 3, 4), Action: 1, Reward: -8
# Step: 134, State: (0, 4, 4), Action: 5, Reward: -9
# Step: 135, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 136, State: (1, 4, 3), Action: 4, Reward: -7
# Step: 137, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 138, State: (0, 4, 3), Action: 5, Reward: -8
# Step: 139, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 140, State: (1, 4, 3), Action: 5, Reward: -9
# Step: 141, State: (2, 4, 3), Action: 1, Reward: -9
# Step: 142, State: (2, 4, 3), Action: 0, Reward: -9
# Step: 143, State: (2, 4, 3), Action: 3, Reward: -10
# Step: 144, State: (2, 4, 4), Action: 5, Reward: -10
# Step: 145, State: (2, 4, 4), Action: 4, Reward: -9
# Step: 146, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 147, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 148, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 149, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 150, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 151, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 152, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 153, State: (1, 3, 1), Action: 0, Reward: -4
# Step: 154, State: (1, 2, 1), Action: 5, Reward: -5
# Step: 155, State: (2, 2, 1), Action: 3, Reward: -6
# Step: 156, State: (2, 2, 2), Action: 1, Reward: -7
# Step: 157, State: (2, 3, 2), Action: 3, Reward: -7
# Step: 158, State: (2, 3, 2), Action: 1, Reward: -8
# Step: 159, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 160, State: (1, 4, 2), Action: 0, Reward: -6
# Step: 161, State: (1, 3, 2), Action: 1, Reward: -7
# Step: 162, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 163, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 164, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 165, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 166, State: (1, 3, 3), Action: 4, Reward: -6
# Step: 167, State: (0, 3, 3), Action: 3, Reward: -7
# Step: 168, State: (0, 3, 4), Action: 3, Reward: -7
# Step: 169, State: (0, 3, 4), Action: 3, Reward: -7
# Step: 170, State: (0, 3, 4), Action: 5, Reward: -8
# Step: 171, State: (1, 3, 4), Action: 1, Reward: -9
# Step: 172, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 173, State: (1, 3, 4), Action: 1, Reward: -9
# Step: 174, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 175, State: (1, 3, 4), Action: 2, Reward: -7
# Step: 176, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 177, State: (1, 4, 3), Action: 5, Reward: -9
# Step: 178, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 179, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 180, State: (1, 4, 2), Action: 5, Reward: -8
# Step: 181, State: (2, 4, 2), Action: 3, Reward: -9
# Step: 182, State: (2, 4, 3), Action: 0, Reward: -9
# Step: 183, State: (2, 4, 3), Action: 3, Reward: -10
# Step: 184, State: (2, 4, 4), Action: 0, Reward: -9
# Step: 185, State: (2, 3, 4), Action: 2, Reward: -9
# Step: 186, State: (2, 3, 4), Action: 0, Reward: -8
# Step: 187, State: (2, 2, 4), Action: 2, Reward: -7
# Step: 188, State: (2, 2, 3), Action: 2, Reward: -6
# Step: 189, State: (2, 2, 2), Action: 2, Reward: -5
# Step: 190, State: (2, 2, 1), Action: 2, Reward: -4
# Step: 191, State: (2, 2, 0), Action: 0, Reward: -3
# Step: 192, State: (2, 1, 0), Action: 2, Reward: -3
# Step: 193, State: (2, 1, 0), Action: 5, Reward: -3
# Step: 194, State: (2, 1, 0), Action: 0, Reward: -2
# Step: 195, State: (2, 0, 0), Action: 3, Reward: -3
# Step: 196, State: (2, 0, 1), Action: 2, Reward: -2
# Step: 197, State: (2, 0, 0), Action: 0, Reward: -2
# Step: 198, State: (2, 0, 0), Action: 4, Reward: -1
# Step: 199, State: (1, 0, 0), Action: 5, Reward: -2
# Step: 200, State: (2, 0, 0), Action: 4, Reward: -1
# Step: 201, State: (1, 0, 0), Action: 5, Reward: -2
# Step: 202, State: (2, 0, 0), Action: 5, Reward: -2
# Step: 203, State: (2, 0, 0), Action: 1, Reward: -3
# Step: 204, State: (2, 1, 0), Action: 3, Reward: -4
# Step: 205, State: (2, 1, 1), Action: 1, Reward: -5
# Step: 206, State: (2, 2, 1), Action: 3, Reward: -6
# Step: 207, State: (2, 2, 2), Action: 3, Reward: -7
# Step: 208, State: (2, 2, 3), Action: 3, Reward: -8
# Step: 209, State: (2, 2, 4), Action: 2, Reward: -7
# Step: 210, State: (2, 2, 3), Action: 4, Reward: -6
# Step: 211, State: (1, 2, 3), Action: 2, Reward: -5
# Step: 212, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 213, State: (1, 1, 2), Action: 4, Reward: -3
# Step: 214, State: (0, 1, 2), Action: 0, Reward: -2
# Step: 215, State: (0, 0, 2), Action: 1, Reward: -3
# Step: 216, State: (0, 1, 2), Action: 0, Reward: -2
# Step: 217, State: (0, 0, 2), Action: 1, Reward: -3
# Step: 218, State: (0, 1, 2), Action: 1, Reward: -3
# Step: 219, State: (0, 1, 2), Action: 4, Reward: -3
# Step: 220, State: (0, 1, 2), Action: 1, Reward: -3
# Step: 221, State: (0, 1, 2), Action: 1, Reward: -3
# Step: 222, State: (0, 1, 2), Action: 2, Reward: -2
# Step: 223, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 224, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 225, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 226, State: (0, 1, 1), Action: 1, Reward: -3
# Step: 227, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 228, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 229, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 230, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 231, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 232, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 233, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 234, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 235, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 236, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 237, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 238, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 239, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 240, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 241, State: (0, 4, 1), Action: 3, Reward: -6
# Step: 242, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 243, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 244, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 245, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 246, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 247, State: (1, 4, 1), Action: 5, Reward: -7
# Step: 248, State: (2, 4, 1), Action: 2, Reward: -6
# Step: 249, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 250, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 251, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 252, State: (2, 4, 0), Action: 5, Reward: -6
# Step: 253, State: (2, 4, 0), Action: 2, Reward: -6
# Step: 254, State: (2, 4, 0), Action: 3, Reward: -7
# Step: 255, State: (2, 4, 1), Action: 1, Reward: -7
# Step: 256, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 257, State: (2, 4, 2), Action: 1, Reward: -8
# Step: 258, State: (2, 4, 2), Action: 0, Reward: -7
# Step: 259, State: (2, 3, 2), Action: 4, Reward: -6
# Step: 260, State: (1, 3, 2), Action: 2, Reward: -5
# Step: 261, State: (1, 3, 1), Action: 5, Reward: -6
# Step: 262, State: (2, 3, 1), Action: 3, Reward: -7
# Step: 263, State: (2, 3, 2), Action: 1, Reward: -8
# Step: 264, State: (2, 4, 2), Action: 3, Reward: -9
# Step: 265, State: (2, 4, 3), Action: 4, Reward: -8
# Step: 266, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 267, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 268, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 269, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 270, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 271, State: (0, 4, 0), Action: 2, Reward: -4
# Step: 272, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 273, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 274, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 275, State: (2, 4, 0), Action: 2, Reward: -6
# Step: 276, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 277, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 278, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 279, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 280, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 281, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 282, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 283, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 284, State: (1, 3, 0), Action: 3, Reward: -5
# Step: 285, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 286, State: (1, 3, 2), Action: 4, Reward: -5
# Step: 287, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 288, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 289, State: (0, 4, 2), Action: 4, Reward: -6
# Step: 290, State: (0, 4, 2), Action: 4, Reward: -6
# Step: 291, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 292, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 293, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 294, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 295, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 296, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 297, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 298, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 299, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 300, State: (0, 4, 0), Action: 2, Reward: -4
# Step: 301, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 302, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 303, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 304, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 305, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 306, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 307, State: (2, 3, 1), Action: 4, Reward: -5
# Step: 308, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 309, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 310, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 311, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 312, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 313, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 314, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 315, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 316, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 317, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 318, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 319, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 320, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 321, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 322, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 323, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 324, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 325, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 326, State: (1, 4, 1), Action: 5, Reward: -7
# Step: 327, State: (2, 4, 1), Action: 2, Reward: -6
# Step: 328, State: (2, 4, 0), Action: 3, Reward: -7
# Step: 329, State: (2, 4, 1), Action: 5, Reward: -7
# Step: 330, State: (2, 4, 1), Action: 5, Reward: -7
# Step: 331, State: (2, 4, 1), Action: 4, Reward: -6
# Step: 332, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 333, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 334, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 335, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 336, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 337, State: (1, 3, 1), Action: 5, Reward: -6
# Step: 338, State: (2, 3, 1), Action: 1, Reward: -7
# Step: 339, State: (2, 4, 1), Action: 4, Reward: -6
# Step: 340, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 341, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 342, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 343, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 344, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 345, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 346, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 347, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 348, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 349, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 350, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 351, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 352, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 353, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 354, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 355, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 356, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 357, State: (1, 4, 2), Action: 0, Reward: -6
# Step: 358, State: (1, 3, 2), Action: 1, Reward: -7
# Step: 359, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 360, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 361, State: (1, 4, 3), Action: 5, Reward: -9
# Step: 362, State: (2, 4, 3), Action: 0, Reward: -9
# Step: 363, State: (2, 4, 3), Action: 1, Reward: -9
# Step: 364, State: (2, 4, 3), Action: 1, Reward: -9
# Step: 365, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 366, State: (2, 4, 2), Action: 2, Reward: -7
# Step: 367, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 368, State: (2, 4, 2), Action: 3, Reward: -9
# Step: 369, State: (2, 4, 3), Action: 3, Reward: -10
# Step: 370, State: (2, 4, 4), Action: 4, Reward: -9
# Step: 371, State: (1, 4, 4), Action: 5, Reward: -10
# Step: 372, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 373, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 374, State: (2, 4, 4), Action: 5, Reward: -10
# Step: 375, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 376, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 377, State: (2, 4, 4), Action: 3, Reward: -10
# Step: 378, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 379, State: (2, 4, 3), Action: 4, Reward: -8
# Step: 380, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 381, State: (1, 4, 3), Action: 4, Reward: -7
# Step: 382, State: (0, 4, 3), Action: 2, Reward: -6
# Step: 383, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 384, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 385, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 386, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 387, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 388, State: (1, 3, 1), Action: 1, Reward: -6
# Step: 389, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 390, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 391, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 392, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 393, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 394, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 395, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 396, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 397, State: (1, 2, 0), Action: 1, Reward: -4
# Step: 398, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 399, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 400, State: (2, 3, 1), Action: 4, Reward: -5
# Step: 401, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 402, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 403, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 404, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 405, State: (0, 2, 0), Action: 3, Reward: -3
# Step: 406, State: (0, 2, 1), Action: 0, Reward: -2
# Step: 407, State: (0, 1, 1), Action: 1, Reward: -3
# Step: 408, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 409, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 410, State: (1, 2, 0), Action: 0, Reward: -2
# Step: 411, State: (1, 1, 0), Action: 1, Reward: -3
# Step: 412, State: (1, 2, 0), Action: 2, Reward: -3
# Step: 413, State: (1, 2, 0), Action: 3, Reward: -4
# Step: 414, State: (1, 2, 1), Action: 2, Reward: -3
# Step: 415, State: (1, 2, 0), Action: 2, Reward: -3
# Step: 416, State: (1, 2, 0), Action: 1, Reward: -4
# Step: 417, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 418, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 419, State: (2, 3, 1), Action: 1, Reward: -7
# Step: 420, State: (2, 4, 1), Action: 5, Reward: -7
# Step: 421, State: (2, 4, 1), Action: 2, Reward: -6
# Step: 422, State: (2, 4, 0), Action: 0, Reward: -5
# Step: 423, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 424, State: (2, 3, 1), Action: 5, Reward: -6
# Step: 425, State: (2, 3, 1), Action: 4, Reward: -5
# Step: 426, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 427, State: (1, 3, 2), Action: 2, Reward: -5
# Step: 428, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 429, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 430, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 431, State: (0, 2, 1), Action: 5, Reward: -4
# Step: 432, State: (1, 2, 1), Action: 5, Reward: -5
# Step: 433, State: (2, 2, 1), Action: 2, Reward: -4
# Step: 434, State: (2, 2, 0), Action: 5, Reward: -4
# Step: 435, State: (2, 2, 0), Action: 2, Reward: -4
# Step: 436, State: (2, 2, 0), Action: 1, Reward: -5
# Step: 437, State: (2, 3, 0), Action: 4, Reward: -4
# Step: 438, State: (1, 3, 0), Action: 3, Reward: -5
# Step: 439, State: (1, 3, 1), Action: 0, Reward: -4
# Step: 440, State: (1, 2, 1), Action: 2, Reward: -3
# Step: 441, State: (1, 2, 0), Action: 4, Reward: -2
# Step: 442, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 443, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 444, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 445, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 446, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 447, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 448, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 449, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 450, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 451, State: (1, 2, 0), Action: 1, Reward: -4
# Step: 452, State: (1, 3, 0), Action: 3, Reward: -5
# Step: 453, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 454, State: (1, 3, 2), Action: 4, Reward: -5
# Step: 455, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 456, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 457, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 458, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 459, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 460, State: (0, 2, 1), Action: 0, Reward: -2
# Step: 461, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 462, State: (0, 1, 1), Action: 0, Reward: -1
# Step: 463, State: (0, 0, 1), Action: 4, Reward: -1
# Step: 464, State: (0, 0, 1), Action: 0, Reward: -1
# Step: 465, State: (0, 0, 1), Action: 1, Reward: -2
# Step: 466, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 467, State: (0, 1, 1), Action: 0, Reward: -1
# Step: 468, State: (0, 0, 1), Action: 5, Reward: -2
# Step: 469, State: (1, 0, 1), Action: 0, Reward: -2
# Step: 470, State: (1, 0, 1), Action: 0, Reward: -2
# Step: 471, State: (1, 0, 1), Action: 0, Reward: -2
# Step: 472, State: (1, 0, 1), Action: 1, Reward: -2
# Step: 473, State: (1, 0, 1), Action: 4, Reward: -1
# Step: 474, State: (0, 0, 1), Action: 1, Reward: -2
# Step: 475, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 476, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 477, State: (0, 1, 1), Action: 3, Reward: -3
# Step: 478, State: (0, 1, 2), Action: 2, Reward: -2
# Step: 479, State: (0, 1, 1), Action: 2, Reward: -1
# Step: 480, State: (0, 1, 0), Action: 5, Reward: -2
# Step: 481, State: (1, 1, 0), Action: 1, Reward: -3
# Step: 482, State: (1, 2, 0), Action: 2, Reward: -3
# Step: 483, State: (1, 2, 0), Action: 4, Reward: -2
# Step: 484, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 485, State: (0, 2, 0), Action: 3, Reward: -3
# Step: 486, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 487, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 488, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 489, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 490, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 491, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 492, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 493, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 494, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 495, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 496, State: (1, 2, 0), Action: 1, Reward: -4
# Step: 497, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 498, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 499, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 500, State: (2, 3, 0), Action: 1, Reward: -6
# Step: 501, State: (2, 4, 0), Action: 0, Reward: -5
# Step: 502, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 503, State: (2, 3, 1), Action: 2, Reward: -5
# Step: 504, State: (2, 3, 0), Action: 0, Reward: -4
# Step: 505, State: (2, 2, 0), Action: 4, Reward: -3
# Step: 506, State: (1, 2, 0), Action: 3, Reward: -4
# Step: 507, State: (1, 2, 1), Action: 5, Reward: -5
# Step: 508, State: (2, 2, 1), Action: 0, Reward: -4
# Step: 509, State: (2, 1, 1), Action: 5, Reward: -4
# Step: 510, State: (2, 1, 1), Action: 2, Reward: -3
# Step: 511, State: (2, 1, 0), Action: 5, Reward: -3
# Step: 512, State: (2, 1, 0), Action: 4, Reward: -2
# Step: 513, State: (1, 1, 0), Action: 4, Reward: -1
# Step: 514, State: (0, 1, 0), Action: 2, Reward: -1
# Step: 515, State: (0, 1, 0), Action: 0, Reward: 100
# Episode 1 finished. Total reward: -2545, Length: 515
# Episode 2 started.
# Step: 1, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 2, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 3, State: (2, 4, 2), Action: 0, Reward: -7
# Step: 4, State: (2, 3, 2), Action: 1, Reward: -8
# Step: 5, State: (2, 4, 2), Action: 3, Reward: -9
# Step: 6, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 7, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 8, State: (1, 4, 2), Action: 0, Reward: -6
# Step: 9, State: (1, 3, 2), Action: 5, Reward: -7
# Step: 10, State: (2, 3, 2), Action: 0, Reward: -6
# Step: 11, State: (2, 2, 2), Action: 4, Reward: -5
# Step: 12, State: (1, 2, 2), Action: 4, Reward: -5
# Step: 13, State: (1, 2, 2), Action: 4, Reward: -5
# Step: 14, State: (1, 2, 2), Action: 5, Reward: -6
# Step: 15, State: (2, 2, 2), Action: 2, Reward: -5
# Step: 16, State: (2, 2, 1), Action: 4, Reward: -4
# Step: 17, State: (1, 2, 1), Action: 5, Reward: -5
# Step: 18, State: (2, 2, 1), Action: 1, Reward: -6
# Step: 19, State: (2, 3, 1), Action: 0, Reward: -5
# Step: 20, State: (2, 2, 1), Action: 4, Reward: -4
# Step: 21, State: (1, 2, 1), Action: 0, Reward: -4
# Step: 22, State: (1, 2, 1), Action: 1, Reward: -5
# Step: 23, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 24, State: (1, 3, 2), Action: 4, Reward: -5
# Step: 25, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 26, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 27, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 28, State: (0, 2, 0), Action: 0, Reward: -1
# Step: 29, State: (0, 1, 0), Action: 3, Reward: -2
# Step: 30, State: (0, 1, 1), Action: 5, Reward: -2
# Step: 31, State: (0, 1, 1), Action: 4, Reward: -2
# Step: 32, State: (0, 1, 1), Action: 1, Reward: -3
# Step: 33, State: (0, 2, 1), Action: 0, Reward: -2
# Step: 34, State: (0, 1, 1), Action: 5, Reward: -2
# Step: 35, State: (0, 1, 1), Action: 2, Reward: -1
# Step: 36, State: (0, 1, 0), Action: 1, Reward: -2
# Step: 37, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 38, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 39, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 40, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 41, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 42, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 43, State: (1, 3, 0), Action: 0, Reward: -3
# Step: 44, State: (1, 2, 0), Action: 5, Reward: -4
# Step: 45, State: (2, 2, 0), Action: 1, Reward: -5
# Step: 46, State: (2, 3, 0), Action: 4, Reward: -4
# Step: 47, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 48, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 49, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 50, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 51, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 52, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 53, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 54, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 55, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 56, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 57, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 58, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 59, State: (1, 2, 0), Action: 2, Reward: -3
# Step: 60, State: (1, 2, 0), Action: 0, Reward: -2
# Step: 61, State: (1, 1, 0), Action: 3, Reward: -2
# Step: 62, State: (1, 1, 0), Action: 0, Reward: -1
# Step: 63, State: (1, 0, 0), Action: 0, Reward: -1
# Step: 64, State: (1, 0, 0), Action: 1, Reward: -2
# Step: 65, State: (1, 1, 0), Action: 4, Reward: -1
# Step: 66, State: (0, 1, 0), Action: 5, Reward: -2
# Step: 67, State: (1, 1, 0), Action: 5, Reward: -3
# Step: 68, State: (2, 1, 0), Action: 4, Reward: -2
# Step: 69, State: (1, 1, 0), Action: 1, Reward: -3
# Step: 70, State: (1, 2, 0), Action: 4, Reward: -2
# Step: 71, State: (0, 2, 0), Action: 0, Reward: -1
# Step: 72, State: (0, 1, 0), Action: 0, Reward: 100
# Episode 2 finished. Total reward: -173, Length: 72
# Episode 3 started.
# Step: 1, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 2, State: (2, 4, 3), Action: 2, Reward: -8
# Step: 3, State: (2, 4, 2), Action: 2, Reward: -7
# Step: 4, State: (2, 4, 1), Action: 5, Reward: -7
# Step: 5, State: (2, 4, 1), Action: 0, Reward: -6
# Step: 6, State: (2, 3, 1), Action: 3, Reward: -7
# Step: 7, State: (2, 3, 2), Action: 0, Reward: -6
# Step: 8, State: (2, 2, 2), Action: 4, Reward: -5
# Step: 9, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 10, State: (1, 1, 2), Action: 2, Reward: -4
# Step: 11, State: (1, 1, 2), Action: 1, Reward: -5
# Step: 12, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 13, State: (1, 1, 2), Action: 3, Reward: -5
# Step: 14, State: (1, 1, 3), Action: 4, Reward: -4
# Step: 15, State: (0, 1, 3), Action: 4, Reward: -4
# Step: 16, State: (0, 1, 3), Action: 1, Reward: -5
# Step: 17, State: (0, 2, 3), Action: 5, Reward: -6
# Step: 18, State: (1, 2, 3), Action: 2, Reward: -5
# Step: 19, State: (1, 2, 2), Action: 4, Reward: -5
# Step: 20, State: (1, 2, 2), Action: 4, Reward: -5
# Step: 21, State: (1, 2, 2), Action: 4, Reward: -5
# Step: 22, State: (1, 2, 2), Action: 3, Reward: -6
# Step: 23, State: (1, 2, 3), Action: 0, Reward: -5
# Step: 24, State: (1, 1, 3), Action: 3, Reward: -6
# Step: 25, State: (1, 1, 4), Action: 1, Reward: -7
# Step: 26, State: (1, 2, 4), Action: 0, Reward: -6
# Step: 27, State: (1, 1, 4), Action: 1, Reward: -7
# Step: 28, State: (1, 2, 4), Action: 1, Reward: -8
# Step: 29, State: (1, 3, 4), Action: 4, Reward: -7
# Step: 30, State: (0, 3, 4), Action: 1, Reward: -8
# Step: 31, State: (0, 4, 4), Action: 2, Reward: -7
# Step: 32, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 33, State: (0, 4, 3), Action: 3, Reward: -8
# Step: 34, State: (0, 4, 4), Action: 1, Reward: -8
# Step: 35, State: (0, 4, 4), Action: 1, Reward: -8
# Step: 36, State: (0, 4, 4), Action: 1, Reward: -8
# Step: 37, State: (0, 4, 4), Action: 0, Reward: -7
# Step: 38, State: (0, 3, 4), Action: 1, Reward: -8
# Step: 39, State: (0, 4, 4), Action: 3, Reward: -8
# Step: 40, State: (0, 4, 4), Action: 2, Reward: -7
# Step: 41, State: (0, 4, 3), Action: 2, Reward: -6
# Step: 42, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 43, State: (0, 3, 2), Action: 0, Reward: -5
# Step: 44, State: (0, 3, 2), Action: 0, Reward: -5
# Step: 45, State: (0, 3, 2), Action: 0, Reward: -5
# Step: 46, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 47, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 48, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 49, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 50, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 51, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 52, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 53, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 54, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 55, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 56, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 57, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 58, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 59, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 60, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 61, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 62, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 63, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 64, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 65, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 66, State: (0, 4, 1), Action: 1, Reward: -5
# Step: 67, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 68, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 69, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 70, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 71, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 72, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 73, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 74, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 75, State: (0, 3, 1), Action: 5, Reward: -5
# Step: 76, State: (1, 3, 1), Action: 1, Reward: -6
# Step: 77, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 78, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 79, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 80, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 81, State: (0, 3, 1), Action: 3, Reward: -5
# Step: 82, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 83, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 84, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 85, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 86, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 87, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 88, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 89, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 90, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 91, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 92, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 93, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 94, State: (2, 3, 1), Action: 2, Reward: -5
# Step: 95, State: (2, 3, 0), Action: 4, Reward: -4
# Step: 96, State: (1, 3, 0), Action: 0, Reward: -3
# Step: 97, State: (1, 2, 0), Action: 1, Reward: -4
# Step: 98, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 99, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 100, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 101, State: (1, 3, 0), Action: 0, Reward: -3
# Step: 102, State: (1, 2, 0), Action: 0, Reward: -2
# Step: 103, State: (1, 1, 0), Action: 4, Reward: -1
# Step: 104, State: (0, 1, 0), Action: 1, Reward: -2
# Step: 105, State: (0, 2, 0), Action: 1, Reward: -3
# Step: 106, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 107, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 108, State: (0, 3, 0), Action: 3, Reward: -4
# Step: 109, State: (0, 3, 1), Action: 5, Reward: -5
# Step: 110, State: (1, 3, 1), Action: 0, Reward: -4
# Step: 111, State: (1, 2, 1), Action: 3, Reward: -5
# Step: 112, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 113, State: (1, 1, 2), Action: 0, Reward: -3
# Step: 114, State: (1, 0, 2), Action: 5, Reward: -4
# Step: 115, State: (2, 0, 2), Action: 1, Reward: -5
# Step: 116, State: (2, 1, 2), Action: 5, Reward: -5
# Step: 117, State: (2, 1, 2), Action: 3, Reward: -6
# Step: 118, State: (2, 1, 3), Action: 5, Reward: -6
# Step: 119, State: (2, 1, 3), Action: 3, Reward: -7
# Step: 120, State: (2, 1, 4), Action: 5, Reward: -7
# Step: 121, State: (2, 1, 4), Action: 3, Reward: -7
# Step: 122, State: (2, 1, 4), Action: 5, Reward: -7
# Step: 123, State: (2, 1, 4), Action: 4, Reward: -6
# Step: 124, State: (1, 1, 4), Action: 1, Reward: -7
# Step: 125, State: (1, 2, 4), Action: 5, Reward: -8
# Step: 126, State: (2, 2, 4), Action: 4, Reward: -7
# Step: 127, State: (1, 2, 4), Action: 5, Reward: -8
# Step: 128, State: (2, 2, 4), Action: 5, Reward: -8
# Step: 129, State: (2, 2, 4), Action: 5, Reward: -8
# Step: 130, State: (2, 2, 4), Action: 4, Reward: -7
# Step: 131, State: (1, 2, 4), Action: 5, Reward: -8
# Step: 132, State: (2, 2, 4), Action: 1, Reward: -9
# Step: 133, State: (2, 3, 4), Action: 2, Reward: -9
# Step: 134, State: (2, 3, 4), Action: 1, Reward: -10
# Step: 135, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 136, State: (2, 4, 4), Action: 0, Reward: -9
# Step: 137, State: (2, 3, 4), Action: 1, Reward: -10
# Step: 138, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 139, State: (2, 4, 3), Action: 5, Reward: -9
# Step: 140, State: (2, 4, 3), Action: 5, Reward: -9
# Step: 141, State: (2, 4, 3), Action: 1, Reward: -9
# Step: 142, State: (2, 4, 3), Action: 0, Reward: -9
# Step: 143, State: (2, 4, 3), Action: 4, Reward: -8
# Step: 144, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 145, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 146, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 147, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 148, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 149, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 150, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 151, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 152, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 153, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 154, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 155, State: (1, 3, 0), Action: 2, Reward: -4
# Step: 156, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 157, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 158, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 159, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 160, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 161, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 162, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 163, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 164, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 165, State: (2, 3, 1), Action: 1, Reward: -7
# Step: 166, State: (2, 4, 1), Action: 4, Reward: -6
# Step: 167, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 168, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 169, State: (0, 3, 1), Action: 4, Reward: -4
# Step: 170, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 171, State: (0, 2, 1), Action: 1, Reward: -4
# Step: 172, State: (0, 3, 1), Action: 3, Reward: -5
# Step: 173, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 174, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 175, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 176, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 177, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 178, State: (0, 4, 2), Action: 5, Reward: -7
# Step: 179, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 180, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 181, State: (0, 4, 1), Action: 3, Reward: -6
# Step: 182, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 183, State: (0, 4, 2), Action: 3, Reward: -7
# Step: 184, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 185, State: (0, 4, 3), Action: 4, Reward: -7
# Step: 186, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 187, State: (0, 4, 3), Action: 0, Reward: -6
# Step: 188, State: (0, 3, 3), Action: 4, Reward: -6
# Step: 189, State: (0, 3, 3), Action: 4, Reward: -6
# Step: 190, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 191, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 192, State: (0, 3, 3), Action: 1, Reward: -7
# Step: 193, State: (0, 4, 3), Action: 3, Reward: -8
# Step: 194, State: (0, 4, 4), Action: 5, Reward: -9
# Step: 195, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 196, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 197, State: (1, 4, 2), Action: 0, Reward: -6
# Step: 198, State: (1, 3, 2), Action: 2, Reward: -5
# Step: 199, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 200, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 201, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 202, State: (1, 4, 1), Action: 0, Reward: -5
# Step: 203, State: (1, 3, 1), Action: 4, Reward: -4
# Step: 204, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 205, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 206, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 207, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 208, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 209, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 210, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 211, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 212, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 213, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 214, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 215, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 216, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 217, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 218, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 219, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 220, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 221, State: (1, 3, 0), Action: 5, Reward: -5
# Step: 222, State: (2, 3, 0), Action: 3, Reward: -6
# Step: 223, State: (2, 3, 1), Action: 2, Reward: -5
# Step: 224, State: (2, 3, 0), Action: 0, Reward: -4
# Step: 225, State: (2, 2, 0), Action: 5, Reward: -4
# Step: 226, State: (2, 2, 0), Action: 3, Reward: -5
# Step: 227, State: (2, 2, 1), Action: 2, Reward: -4
# Step: 228, State: (2, 2, 0), Action: 1, Reward: -5
# Step: 229, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 230, State: (2, 3, 0), Action: 0, Reward: -4
# Step: 231, State: (2, 2, 0), Action: 1, Reward: -5
# Step: 232, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 233, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 234, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 235, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 236, State: (2, 3, 0), Action: 1, Reward: -6
# Step: 237, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 238, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 239, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 240, State: (2, 4, 0), Action: 5, Reward: -6
# Step: 241, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 242, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 243, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 244, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 245, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 246, State: (0, 2, 0), Action: 3, Reward: -3
# Step: 247, State: (0, 2, 1), Action: 3, Reward: -3
# Step: 248, State: (0, 2, 1), Action: 4, Reward: -3
# Step: 249, State: (0, 2, 1), Action: 1, Reward: -4
# Step: 250, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 251, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 252, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 253, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 254, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 255, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 256, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 257, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 258, State: (1, 4, 0), Action: 0, Reward: -4
# Step: 259, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 260, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 261, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 262, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 263, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 264, State: (0, 4, 0), Action: 5, Reward: -5
# Step: 265, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 266, State: (1, 4, 1), Action: 3, Reward: -7
# Step: 267, State: (1, 4, 2), Action: 2, Reward: -6
# Step: 268, State: (1, 4, 1), Action: 1, Reward: -6
# Step: 269, State: (1, 4, 1), Action: 2, Reward: -5
# Step: 270, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 271, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 272, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 273, State: (2, 4, 0), Action: 0, Reward: -5
# Step: 274, State: (2, 3, 0), Action: 4, Reward: -4
# Step: 275, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 276, State: (1, 4, 0), Action: 3, Reward: -6
# Step: 277, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 278, State: (0, 4, 1), Action: 3, Reward: -6
# Step: 279, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 280, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 281, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 282, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 283, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 284, State: (0, 3, 0), Action: 1, Reward: -4
# Step: 285, State: (0, 4, 0), Action: 4, Reward: -4
# Step: 286, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 287, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 288, State: (1, 3, 0), Action: 4, Reward: -3
# Step: 289, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 290, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 291, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 292, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 293, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 294, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 295, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 296, State: (0, 4, 1), Action: 3, Reward: -6
# Step: 297, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 298, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 299, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 300, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 301, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 302, State: (0, 3, 2), Action: 5, Reward: -6
# Step: 303, State: (1, 3, 2), Action: 4, Reward: -5
# Step: 304, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 305, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 306, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 307, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 308, State: (0, 3, 3), Action: 4, Reward: -6
# Step: 309, State: (0, 3, 3), Action: 0, Reward: -5
# Step: 310, State: (0, 2, 3), Action: 0, Reward: -4
# Step: 311, State: (0, 1, 3), Action: 5, Reward: -5
# Step: 312, State: (1, 1, 3), Action: 1, Reward: -6
# Step: 313, State: (1, 2, 3), Action: 1, Reward: -7
# Step: 314, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 315, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 316, State: (1, 3, 3), Action: 2, Reward: -6
# Step: 317, State: (1, 3, 2), Action: 0, Reward: -5
# Step: 318, State: (1, 2, 2), Action: 2, Reward: -4
# Step: 319, State: (1, 2, 1), Action: 4, Reward: -3
# Step: 320, State: (0, 2, 1), Action: 1, Reward: -4
# Step: 321, State: (0, 3, 1), Action: 5, Reward: -5
# Step: 322, State: (1, 3, 1), Action: 0, Reward: -4
# Step: 323, State: (1, 2, 1), Action: 1, Reward: -5
# Step: 324, State: (1, 3, 1), Action: 5, Reward: -6
# Step: 325, State: (2, 3, 1), Action: 1, Reward: -7
# Step: 326, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 327, State: (2, 4, 2), Action: 5, Reward: -8
# Step: 328, State: (2, 4, 2), Action: 2, Reward: -7
# Step: 329, State: (2, 4, 1), Action: 5, Reward: -7
# Step: 330, State: (2, 4, 1), Action: 2, Reward: -6
# Step: 331, State: (2, 4, 0), Action: 0, Reward: -5
# Step: 332, State: (2, 3, 0), Action: 4, Reward: -4
# Step: 333, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 334, State: (1, 4, 0), Action: 2, Reward: -5
# Step: 335, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 336, State: (1, 4, 0), Action: 4, Reward: -4
# Step: 337, State: (0, 4, 0), Action: 3, Reward: -5
# Step: 338, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 339, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 340, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 341, State: (0, 4, 1), Action: 5, Reward: -6
# Step: 342, State: (1, 4, 1), Action: 4, Reward: -5
# Step: 343, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 344, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 345, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 346, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 347, State: (1, 3, 0), Action: 2, Reward: -4
# Step: 348, State: (1, 3, 0), Action: 0, Reward: -3
# Step: 349, State: (1, 2, 0), Action: 0, Reward: -2
# Step: 350, State: (1, 1, 0), Action: 1, Reward: -3
# Step: 351, State: (1, 2, 0), Action: 4, Reward: -2
# Step: 352, State: (0, 2, 0), Action: 3, Reward: -3
# Step: 353, State: (0, 2, 1), Action: 0, Reward: -2
# Step: 354, State: (0, 1, 1), Action: 2, Reward: -1
# Step: 355, State: (0, 1, 0), Action: 3, Reward: -2
# Step: 356, State: (0, 1, 1), Action: 4, Reward: -2
# ...
# Step: 270, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 271, State: (2, 4, 2), Action: 5, Reward: -8
# Step: 272, State: (2, 4, 2), Action: 5, Reward: -8
# Step: 273, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 274, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 275, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 276, State: (0, 4, 2), Action: 5, Reward: -7
# Step: 277, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 278, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 279, State: (0, 4, 2), Action: 1, Reward: -6
# Step: 280, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 281, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 282, State: (0, 4, 2), Action: 3, Reward: -7
# Step: 283, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 284, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 285, State: (0, 4, 3), Action: 2, Reward: -6
# Step: 286, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 287, State: (0, 3, 2), Action: 2, Reward: -4
# Step: 288, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 289, State: (0, 3, 0), Action: 2, Reward: -3
# Step: 290, State: (0, 3, 0), Action: 0, Reward: -2
# Step: 291, State: (0, 2, 0), Action: 4, Reward: -2
# Step: 292, State: (0, 2, 0), Action: 0, Reward: -1
# Step: 293, State: (0, 1, 0), Action: 1, Reward: -2
# Step: 294, State: (0, 2, 0), Action: 2, Reward: -2
# Step: 295, State: (0, 2, 0), Action: 3, Reward: -3
# Step: 296, State: (0, 2, 1), Action: 1, Reward: -4
# Step: 297, State: (0, 3, 1), Action: 1, Reward: -5
# Step: 298, State: (0, 4, 1), Action: 4, Reward: -5
# Step: 299, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 300, State: (0, 3, 1), Action: 3, Reward: -5
# Step: 301, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 302, State: (0, 4, 2), Action: 5, Reward: -7
# Step: 303, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 304, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 305, State: (0, 4, 1), Action: 0, Reward: -4
# Step: 306, State: (0, 3, 1), Action: 0, Reward: -3
# Step: 307, State: (0, 2, 1), Action: 2, Reward: -2
# Step: 308, State: (0, 2, 0), Action: 5, Reward: -3
# Step: 309, State: (1, 2, 0), Action: 5, Reward: -4
# Step: 310, State: (2, 2, 0), Action: 0, Reward: -3
# Step: 311, State: (2, 1, 0), Action: 5, Reward: -3
# Step: 312, State: (2, 1, 0), Action: 3, Reward: -4
# Step: 313, State: (2, 1, 1), Action: 0, Reward: -3
# Step: 314, State: (2, 0, 1), Action: 2, Reward: -2
# Step: 315, State: (2, 0, 0), Action: 5, Reward: -2
# Step: 316, State: (2, 0, 0), Action: 4, Reward: -1
# Step: 317, State: (1, 0, 0), Action: 3, Reward: -2
# Step: 318, State: (1, 0, 1), Action: 5, Reward: -3
# Step: 319, State: (2, 0, 1), Action: 0, Reward: -3
# Step: 320, State: (2, 0, 1), Action: 2, Reward: -2
# Step: 321, State: (2, 0, 0), Action: 5, Reward: -2
# Step: 322, State: (2, 0, 0), Action: 0, Reward: -2
# Step: 323, State: (2, 0, 0), Action: 2, Reward: -2
# Step: 324, State: (2, 0, 0), Action: 0, Reward: -2
# Step: 325, State: (2, 0, 0), Action: 0, Reward: -2
# Step: 326, State: (2, 0, 0), Action: 0, Reward: -2
# Step: 327, State: (2, 0, 0), Action: 5, Reward: -2
# Step: 328, State: (2, 0, 0), Action: 4, Reward: -1
# Step: 329, State: (1, 0, 0), Action: 0, Reward: -1
# Step: 330, State: (1, 0, 0), Action: 0, Reward: -1
# Step: 331, State: (1, 0, 0), Action: 4, Reward: 100
# Episode 9 finished. Total reward: -1686, Length: 331
# Episode 10 started.
# Step: 1, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 2, State: (2, 4, 3), Action: 3, Reward: -10
# Step: 3, State: (2, 4, 4), Action: 5, Reward: -10
# Step: 4, State: (2, 4, 4), Action: 5, Reward: -10
# Step: 5, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 6, State: (2, 4, 4), Action: 3, Reward: -10
# Step: 7, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 8, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 9, State: (2, 4, 4), Action: 1, Reward: -10
# Step: 10, State: (2, 4, 4), Action: 0, Reward: -9
# Step: 11, State: (2, 3, 4), Action: 2, Reward: -9
# Step: 12, State: (2, 3, 4), Action: 0, Reward: -8
# Step: 13, State: (2, 2, 4), Action: 2, Reward: -7
# Step: 14, State: (2, 2, 3), Action: 5, Reward: -7
# Step: 15, State: (2, 2, 3), Action: 5, Reward: -7
# Step: 16, State: (2, 2, 3), Action: 2, Reward: -6
# Step: 17, State: (2, 2, 2), Action: 2, Reward: -5
# Step: 18, State: (2, 2, 1), Action: 4, Reward: -4
# Step: 19, State: (1, 2, 1), Action: 5, Reward: -5
# Step: 20, State: (2, 2, 1), Action: 4, Reward: -4
# Step: 21, State: (1, 2, 1), Action: 0, Reward: -4
# Step: 22, State: (1, 2, 1), Action: 4, Reward: -3
# Step: 23, State: (0, 2, 1), Action: 0, Reward: -2
# Step: 24, State: (0, 1, 1), Action: 1, Reward: -3
# Step: 25, State: (0, 2, 1), Action: 4, Reward: -3
# Step: 26, State: (0, 2, 1), Action: 1, Reward: -4
# Step: 27, State: (0, 3, 1), Action: 2, Reward: -3
# Step: 28, State: (0, 3, 0), Action: 4, Reward: -3
# Step: 29, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 30, State: (1, 3, 0), Action: 3, Reward: -5
# Step: 31, State: (1, 3, 1), Action: 3, Reward: -6
# Step: 32, State: (1, 3, 2), Action: 1, Reward: -7
# Step: 33, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 34, State: (0, 4, 2), Action: 5, Reward: -7
# Step: 35, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 36, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 37, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 38, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 39, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 40, State: (1, 4, 4), Action: 3, Reward: -9
# Step: 41, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 42, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 43, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 44, State: (1, 4, 4), Action: 1, Reward: -9
# Step: 45, State: (1, 4, 4), Action: 1, Reward: -9
# Step: 46, State: (1, 4, 4), Action: 1, Reward: -9
# Step: 47, State: (1, 4, 4), Action: 3, Reward: -9
# Step: 48, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 49, State: (1, 3, 4), Action: 0, Reward: -7
# Step: 50, State: (1, 2, 4), Action: 1, Reward: -8
# Step: 51, State: (1, 3, 4), Action: 2, Reward: -7
# Step: 52, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 53, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 54, State: (1, 3, 3), Action: 5, Reward: -7
# Step: 55, State: (1, 3, 3), Action: 4, Reward: -6
# Step: 56, State: (0, 3, 3), Action: 3, Reward: -7
# Step: 57, State: (0, 3, 4), Action: 5, Reward: -8
# Step: 58, State: (1, 3, 4), Action: 5, Reward: -9
# Step: 59, State: (2, 3, 4), Action: 1, Reward: -10
# Step: 60, State: (2, 4, 4), Action: 5, Reward: -10
# Step: 61, State: (2, 4, 4), Action: 0, Reward: -9
# Step: 62, State: (2, 3, 4), Action: 1, Reward: -10
# Step: 63, State: (2, 4, 4), Action: 2, Reward: -9
# Step: 64, State: (2, 4, 3), Action: 4, Reward: -8
# Step: 65, State: (1, 4, 3), Action: 4, Reward: -7
# Step: 66, State: (0, 4, 3), Action: 2, Reward: -6
# Step: 67, State: (0, 4, 2), Action: 3, Reward: -7
# Step: 68, State: (0, 4, 3), Action: 0, Reward: -6
# Step: 69, State: (0, 3, 3), Action: 4, Reward: -6
# Step: 70, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 71, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 72, State: (0, 3, 3), Action: 0, Reward: -5
# Step: 73, State: (0, 2, 3), Action: 1, Reward: -6
# Step: 74, State: (0, 3, 3), Action: 3, Reward: -7
# Step: 75, State: (0, 3, 4), Action: 4, Reward: -7
# Step: 76, State: (0, 3, 4), Action: 3, Reward: -7
# Step: 77, State: (0, 3, 4), Action: 4, Reward: -7
# Step: 78, State: (0, 3, 4), Action: 3, Reward: -7
# Step: 79, State: (0, 3, 4), Action: 0, Reward: -6
# Step: 80, State: (0, 2, 4), Action: 0, Reward: -5
# Step: 81, State: (0, 1, 4), Action: 5, Reward: -6
# Step: 82, State: (1, 1, 4), Action: 4, Reward: -5
# Step: 83, State: (0, 1, 4), Action: 5, Reward: -6
# Step: 84, State: (1, 1, 4), Action: 3, Reward: -6
# Step: 85, State: (1, 1, 4), Action: 1, Reward: -7
# Step: 86, State: (1, 2, 4), Action: 1, Reward: -8
# Step: 87, State: (1, 3, 4), Action: 0, Reward: -7
# Step: 88, State: (1, 2, 4), Action: 5, Reward: -8
# Step: 89, State: (2, 2, 4), Action: 1, Reward: -9
# Step: 90, State: (2, 3, 4), Action: 4, Reward: -8
# Step: 91, State: (1, 3, 4), Action: 2, Reward: -7
# Step: 92, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 93, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 94, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 95, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 96, State: (1, 4, 4), Action: 3, Reward: -9
# Step: 97, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 98, State: (1, 3, 4), Action: 1, Reward: -9
# Step: 99, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 100, State: (1, 3, 4), Action: 0, Reward: -7
# Step: 101, State: (1, 2, 4), Action: 1, Reward: -8
# Step: 102, State: (1, 3, 4), Action: 1, Reward: -9
# Step: 103, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 104, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 105, State: (1, 4, 4), Action: 3, Reward: -9
# Step: 106, State: (1, 4, 4), Action: 0, Reward: -8
# Step: 107, State: (1, 3, 4), Action: 4, Reward: -7
# Step: 108, State: (0, 3, 4), Action: 1, Reward: -8
# Step: 109, State: (0, 4, 4), Action: 2, Reward: -7
# Step: 110, State: (0, 4, 3), Action: 4, Reward: -7
# Step: 111, State: (0, 4, 3), Action: 0, Reward: -6
# Step: 112, State: (0, 3, 3), Action: 1, Reward: -7
# Step: 113, State: (0, 4, 3), Action: 1, Reward: -7
# Step: 114, State: (0, 4, 3), Action: 5, Reward: -8
# Step: 115, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 116, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 117, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 118, State: (1, 4, 3), Action: 0, Reward: -7
# Step: 119, State: (1, 3, 3), Action: 1, Reward: -8
# Step: 120, State: (1, 4, 3), Action: 2, Reward: -7
# Step: 121, State: (1, 4, 2), Action: 1, Reward: -7
# Step: 122, State: (1, 4, 2), Action: 3, Reward: -8
# Step: 123, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 124, State: (1, 4, 4), Action: 2, Reward: -8
# Step: 125, State: (1, 4, 3), Action: 5, Reward: -9
# Step: 126, State: (2, 4, 3), Action: 0, Reward: -9
# Step: 127, State: (2, 4, 3), Action: 1, Reward: -9
# Step: 128, State: (2, 4, 3), Action: 4, Reward: -8
# Step: 129, State: (1, 4, 3), Action: 1, Reward: -8
# Step: 130, State: (1, 4, 3), Action: 3, Reward: -9
# Step: 131, State: (1, 4, 4), Action: 4, Reward: -8
# Step: 132, State: (0, 4, 4), Action: 2, Reward: -7
# Step: 133, State: (0, 4, 3), Action: 4, Reward: -7
# Step: 134, State: (0, 4, 3), Action: 0, Reward: -6
# Step: 135, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 136, State: (0, 3, 2), Action: 5, Reward: -6
# Step: 137, State: (1, 3, 2), Action: 2, Reward: -5
# Step: 138, State: (1, 3, 1), Action: 5, Reward: -6
# Step: 139, State: (2, 3, 1), Action: 1, Reward: -7
# Step: 140, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 141, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 142, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 143, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 144, State: (0, 3, 2), Action: 5, Reward: -6
# Step: 145, State: (1, 3, 2), Action: 5, Reward: -7
# Step: 146, State: (2, 3, 2), Action: 4, Reward: -6
# Step: 147, State: (1, 3, 2), Action: 5, Reward: -7
# Step: 148, State: (2, 3, 2), Action: 1, Reward: -8
# Step: 149, State: (2, 4, 2), Action: 4, Reward: -7
# Step: 150, State: (1, 4, 2), Action: 4, Reward: -6
# Step: 151, State: (0, 4, 2), Action: 0, Reward: -5
# Step: 152, State: (0, 3, 2), Action: 4, Reward: -5
# Step: 153, State: (0, 3, 2), Action: 3, Reward: -6
# Step: 154, State: (0, 3, 3), Action: 4, Reward: -6
# Step: 155, State: (0, 3, 3), Action: 5, Reward: -7
# Step: 156, State: (1, 3, 3), Action: 3, Reward: -8
# Step: 157, State: (1, 3, 4), Action: 0, Reward: -7
# Step: 158, State: (1, 2, 4), Action: 0, Reward: -6
# Step: 159, State: (1, 1, 4), Action: 1, Reward: -7
# Step: 160, State: (1, 2, 4), Action: 2, Reward: -6
# Step: 161, State: (1, 2, 3), Action: 4, Reward: -5
# Step: 162, State: (0, 2, 3), Action: 2, Reward: -5
# Step: 163, State: (0, 2, 3), Action: 1, Reward: -6
# Step: 164, State: (0, 3, 3), Action: 2, Reward: -5
# Step: 165, State: (0, 3, 2), Action: 0, Reward: -5
# Step: 166, State: (0, 3, 2), Action: 1, Reward: -6
# Step: 167, State: (0, 4, 2), Action: 4, Reward: -6
# Step: 168, State: (0, 4, 2), Action: 2, Reward: -5
# Step: 169, State: (0, 4, 1), Action: 2, Reward: -4
# Step: 170, State: (0, 4, 0), Action: 1, Reward: -4
# Step: 171, State: (0, 4, 0), Action: 0, Reward: -3
# Step: 172, State: (0, 3, 0), Action: 5, Reward: -4
# Step: 173, State: (1, 3, 0), Action: 2, Reward: -4
# Step: 174, State: (1, 3, 0), Action: 1, Reward: -5
# Step: 175, State: (1, 4, 0), Action: 1, Reward: -5
# Step: 176, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 177, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 178, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 179, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 180, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 181, State: (2, 4, 0), Action: 2, Reward: -6
# Step: 182, State: (2, 4, 0), Action: 0, Reward: -5
# Step: 183, State: (2, 3, 0), Action: 5, Reward: -5
# Step: 184, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 185, State: (2, 3, 0), Action: 2, Reward: -5
# Step: 186, State: (2, 3, 0), Action: 1, Reward: -6
# Step: 187, State: (2, 4, 0), Action: 4, Reward: -5
# Step: 188, State: (1, 4, 0), Action: 5, Reward: -6
# Step: 189, State: (2, 4, 0), Action: 1, Reward: -6
# Step: 190, State: (2, 4, 0), Action: 3, Reward: -7
# Step: 191, State: (2, 4, 1), Action: 3, Reward: -8
# Step: 192, State: (2, 4, 2), Action: 1, Reward: -8
# Step: 193, State: (2, 4, 2), Action: 1, Reward: -8
# Step: 194, State: (2, 4, 2), Action: 0, Reward: -7
# Step: 195, State: (2, 3, 2), Action: 5, Reward: -7
# Step: 196, State: (2, 3, 2), Action: 4, Reward: -6
# Step: 197, State: (1, 3, 2), Action: 3, Reward: -7
# Step: 198, State: (1, 3, 3), Action: 3, Reward: -8
# Step: 199, State: (1, 3, 4), Action: 2, Reward: -7
# Step: 200, State: (1, 3, 3), Action: 0, Reward: -6
# Step: 201, State: (1, 2, 3), Action: 5, Reward: -7
# Step: 202, State: (2, 2, 3), Action: 2, Reward: -6
# Step: 203, State: (2, 2, 2), Action: 0, Reward: -5
# Step: 204, State: (2, 1, 2), Action: 0, Reward: -4
# Step: 205, State: (2, 0, 2), Action: 1, Reward: -5
# Step: 206, State: (2, 1, 2), Action: 5, Reward: -5
# Step: 207, State: (2, 1, 2), Action: 5, Reward: -5
# Step: 208, State: (2, 1, 2), Action: 0, Reward: -4
# Step: 209, State: (2, 0, 2), Action: 1, Reward: -5
# Step: 210, State: (2, 1, 2), Action: 4, Reward: -4
# Step: 211, State: (1, 1, 2), Action: 1, Reward: -5
# Step: 212, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 213, State: (1, 1, 2), Action: 2, Reward: -4
# Step: 214, State: (1, 1, 2), Action: 1, Reward: -5
# Step: 215, State: (1, 2, 2), Action: 0, Reward: -4
# Step: 216, State: (1, 1, 2), Action: 0, Reward: -3
# Step: 217, State: (1, 0, 2), Action: 5, Reward: -4
# Step: 218, State: (2, 0, 2), Action: 4, Reward: -3
# Step: 219, State: (1, 0, 2), Action: 3, Reward: -4
# Step: 220, State: (1, 0, 3), Action: 2, Reward: -3
# Step: 221, State: (1, 0, 2), Action: 1, Reward: -4
# Step: 222, State: (1, 1, 2), Action: 5, Reward: -5
# Step: 223, State: (2, 1, 2), Action: 1, Reward: -6
# Step: 224, State: (2, 2, 2), Action: 4, Reward: -5
# Step: 225, State: (1, 2, 2), Action: 2, Reward: -4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7 # Anomaly detection 활성화
#       8 torch.autograd.set_detect_anomaly(True)
# ----> 9 episode_rewards, episode_lengths = agent.train(num_episodes=1000)
#      12 # 학습 결과 저장
#      13 torch.save(agent.policy_net.state_dict(), 'policy_net.pth')
#
# Cell In[5], line 175, in PPOAgent.train(self, num_episodes)
#     173 done = False
#     174 while not done:
# --> 175     action, log_prob = agent.select_action(state)
#     176     next_state, reward, done = env.step(action)
#     178     # 추가된 로깅: 각 단계의 상태, 보상, 행동 출력
#
# Cell In[5], line 115, in PPOAgent.select_action(self, state)
#     113     probs = self.policy_net(state_tensor)
#     114     dist = Categorical(probs)
# --> 115     action = dist.sample()
#     116     log_prob = dist.log_prob(action)
#     117 return action.item(), log_prob
#
# File ~\anaconda3\envs\rein\lib\site-packages\torch\distributions\categorical.py:132, in Categorical.sample(self, sample_shape)
#     130     sample_shape = torch.Size(sample_shape)
#     131 probs_2d = self.probs.reshape(-1, self._num_events)
# --> 132 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     133 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# KeyboardInterrupt:
